# %% [markdown]
# <a href="https://colab.research.google.com/github/choisubeen/Python-Algorithm_Study_2022_05/blob/soop/%EC%B5%9C%EC%88%98%EB%B9%88/BaekJoon/%ED%95%A8%EC%88%981.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# n번째 정수까지 덧셈
def calcul(a):
    ans = 0
    for i in a:
        ans+=i
    return ans
